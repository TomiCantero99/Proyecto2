# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/fotoapp_proyecto2')

import fotoapp as f

# %%
img = f.cargar_y_redimensionar("/content/drive/MyDrive/fotoapp_proyecto2/imagenes/oso_polar.jpg", "Instagram")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1350>

# %%
eco = f.ecualizar_contraste(img)
eco
# Out:
# <PIL.Image.Image image mode=L size=1080x1350>

# %%
filt = f.aplicar_filtro(img, "smooth")
filt
# Out:
# <PIL.Image.Image image mode=RGB size=1080x1350>
